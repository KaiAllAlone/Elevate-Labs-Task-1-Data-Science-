# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('netflix_titles.csv')

# %%
df.describe().T
# Out:
#                count         mean       std     min     25%     50%     75%  \
# release_year  8807.0  2014.180198  8.819312  1925.0  2013.0  2017.0  2019.0
#
#                  max
# release_year  2021.0

# %%
df.sample(10)
# Out:
#      show_id     type                            title  \
# 1249   s1250    Movie  Blanche Gardin: The All-Nighter
# 1892   s1893    Movie  A Go! Go! Cory Carson Halloween
# 1718   s1719  TV Show                          Trial 4
# 4966   s4967    Movie     Trailer Park Boys: The Movie
# 5966   s5967    Movie                           15-Aug
# 4701   s4702    Movie               For Here or to Go?
# 5732   s5733  TV Show                         Love Now
# 3113   s3114    Movie                  Falz Experience
# 7450   s7451    Movie    Mi Shivajiraje Bhosale Boltoy
# 1990   s1991  TV Show                       Challenger
#
#                                  director  \
# 1249  Xavier Maingon, Marc-Antoine Hélard
# 1892              Alex Woo, Stanley Moore
# 1718                                  NaN
# 4966                     Mike Clattenburg
# 5966                   Swapnaneel Jayakar
# 4701                    Rucha Humnabadkar
# 5732                                  NaN
# 3113                                 Falz
# 7450                    Santosh Manjrekar
# 1990                                  NaN
#
#                                                    cast               country  \
# 1249                                     Blanche Gardin                   NaN
# 1892  Alan C. Lim, Smith Foreman, Maisie Benson, Ann...                   NaN
# 1718                                                NaN         United States
# 4966  Robb Wells, John Paul Tremblay, Mike Smith, Lu...                Canada
# 5966  Rahul Pethe, Mrunmayee Deshpande, Adinath Koth...                 India
# 4701  Ali Fazal, Melanie Chandra, Rajit Kapoor, Amit...  United States, India
# 5732  Annie Chen, George Hu, Bobby Dou, Vivi Lee, Ha...                Taiwan
# 3113      Falz, Adunni Ade, Bisola Aiyeola, Frank Donga                   NaN
# 7450  Sachin Khedekar, Mahesh Manjrekar, Makarand An...                 India
# 1990                                                NaN         United States
#
#               date_added  release_year rating  duration  \
# 1249       March 1, 2021          2021  TV-MA    96 min
# 1892     October 2, 2020          2020   TV-Y    22 min
# 1718   November 11, 2020          2020  TV-MA  1 Season
# 4966      March 30, 2018          2006      R    95 min
# 5966      March 29, 2019          2019  TV-14   124 min
# 4701     August 15, 2018          2015  TV-MA   105 min
# 5732    November 1, 2016          2012  TV-14  1 Season
# 3113   December 20, 2019          2018  TV-MA    82 min
# 7450     January 1, 2018          2009  TV-14   148 min
# 1990  September 16, 2020          2020  TV-14  1 Season
#
#                                               listed_in  \
# 1249                                    Stand-Up Comedy
# 1892                           Children & Family Movies
# 1718                         Crime TV Shows, Docuseries
# 4966                              Comedies, Cult Movies
# 5966               Comedies, Dramas, Independent Movies
# 4701               Comedies, Dramas, Independent Movies
# 5732  International TV Shows, Romantic TV Shows, TV ...
# 3113             International Movies, Music & Musicals
# 7450   Comedies, International Movies, Sci-Fi & Fantasy
# 1990                    Docuseries, Science & Nature TV
#
#                                             description
# 1249  With self-deprecating humor, French comic Blan...
# 1892  Cory, Chrissy and Freddie are on the hunt for ...
# 1718  Charged as a teen in the 1993 killing of a Bos...
# 4966  In this feature-length adventure, Ricky, Julia...
# 5966  On India's Independence Day, a zany mishap in ...
# 4701  A software engineer must decide if he'd rather...
# 5732  When her loved ones cook up a morbid plan to m...
# 3113  Playing multiple characters, from lawyer to pr...
# 7450  After a disgruntled man blames his Marathi her...
# 1990  Engineers, officials and the crew members' fam...

# %% [markdown]
# <h1 style="color:#39FF14;font-size:40px;"> Drop the duplicates</h1>

# %%
df=df.drop_duplicates()

# %% [markdown]
# <h1 style="color:#39FF14;font-size:40px;"> Check for NULL values</h1>

# %%
df.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# <h2 style= "color:#87CEEB; "> We can encode the missing 'director','country' and 'cast' column with either 'most frequent' or a seperate class called 'Unknown'</h2>

# %%
def replace_na_with_unknown(x):
    if not pd.isna(x):
        return x
    else:
        return 'Unknown'

# %%
df['director']=df['director'].apply(replace_na_with_unknown)
df['country']=df['country'].apply(replace_na_with_unknown)
df['cast']=df['cast'].apply(replace_na_with_unknown)

# %% [markdown]
# <h2 style= "color:#87CEEB; "> Replace NaN 'date_added','duration' and 'rating' with the mode(most frequent)</h2>

# %%
def rep_mode(df,col):
    mode=df[col].mode()[0]
    df[col]=df[col].fillna(mode)
    return df

# %%
df=rep_mode(df,'date_added')
df=rep_mode(df,'rating')
df=rep_mode(df,'duration')

# %%
df.isna().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %% [markdown]
# <h1 style="color:#39FF14;font-size:40px;"> Fixing Data Types</h1>

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water          Unknown
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans          Unknown
# 4      s5  TV Show           Kota Factory          Unknown
#
#                                                 cast        country  \
# 0                                            Unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# 3                                            Unknown        Unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %% [markdown]
# <h2 style= "color:#87CEEB; "> Date column to datetime dtype</h2>

# %%
df['date_added']=df['date_added'].apply(lambda x: x.strip())

# %%
df['date_added']=pd.to_datetime(df['date_added'])

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water          Unknown
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans          Unknown
# 4      s5  TV Show           Kota Factory          Unknown
#
#                                                 cast        country  \
# 0                                            Unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# 3                                            Unknown        Unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# 3 2021-09-24          2021  TV-MA   1 Season
# 4 2021-09-24          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %% [markdown]
# <h2 style= "color:#87CEEB; "> Convert columns which have multiple names 'cast','country','listed_in' and 'director' to be a list containing strings</h2>

# %%
def con_mstring_list(x):
    return x.split(',')

# %%
df['cast']=df['cast'].apply(con_mstring_list)
df['country']=df['country'].apply(con_mstring_list)
df['listed_in']=df['listed_in'].apply(con_mstring_list)
df['director']=df['director'].apply(con_mstring_list)

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water          Unknown
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans          Unknown
# 4      s5  TV Show           Kota Factory          Unknown
#
#                                                 cast          country  \
# 0                                          [Unknown]  [United States]
# 1  [Ama Qamata,  Khosi Ngema,  Gail Mabalane,  Th...   [South Africa]
# 2  [Sami Bouajila,  Tracy Gotoas,  Samuel Jouy,  ...        [Unknown]
# 3                                          [Unknown]        [Unknown]
# 4  [Mayur More,  Jitendra Kumar,  Ranjan Raj,  Al...          [India]
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# 3 2021-09-24          2021  TV-MA   1 Season
# 4 2021-09-24          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                    [Documentaries]
# 1  [International TV Shows,  TV Dramas,  TV Myste...
# 2  [Crime TV Shows,  International TV Shows,  TV ...
# 3                          [Docuseries,  Reality TV]
# 4  [International TV Shows,  Romantic TV Shows,  ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %% [markdown]
# <h2 style= "color:#87CEEB; "> Create a new column for seasons and a seperate for duration in minutes</h2>

# %%
durations
# Out:
#       index   duration
# 0         0     90 min
# 1         1  2 Seasons
# 2         2   1 Season
# 3         3   1 Season
# 4         4  2 Seasons
# ...     ...        ...
# 8802   8802    158 min
# 8803   8803  2 Seasons
# 8804   8804     88 min
# 8805   8805     88 min
# 8806   8806    111 min
#
# [8807 rows x 2 columns]

# %% [markdown]
# <h3> Show the unique categories:</h3>

# %%
((durations['duration'].apply(lambda x:x.split()[1])).reset_index())['duration'].unique()
# Out:
# array(['min', 'Seasons', 'Season'], dtype=object)

# %%
durations=df.iloc[:,9].reset_index()
mins=[]
seasons=[]
for  a in durations['duration']:
    if a.split()[1]=='Season' or a.split()[1]=='Seasons':
        seasons.append(int(a.split()[0]))
        mins.append(-1)
    else:
        mins.append(int(a.split()[0]))
        seasons.append(-1)

# %%
df['minutes']=mins
df['seasons']=seasons
df=df.drop(columns=['duration'])

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          Unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          Unknown
# 4         s5  TV Show           Kota Factory          Unknown
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb          Unknown
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast          country  \
# 0                                             [Unknown]  [United States]
# 1     [Ama Qamata,  Khosi Ngema,  Gail Mabalane,  Th...   [South Africa]
# 2     [Sami Bouajila,  Tracy Gotoas,  Samuel Jouy,  ...        [Unknown]
# 3                                             [Unknown]        [Unknown]
# 4     [Mayur More,  Jitendra Kumar,  Ranjan Raj,  Al...          [India]
# ...                                                 ...              ...
# 8802  [Mark Ruffalo,  Jake Gyllenhaal,  Robert Downe...  [United States]
# 8803                                          [Unknown]        [Unknown]
# 8804  [Jesse Eisenberg,  Woody Harrelson,  Emma Ston...  [United States]
# 8805  [Tim Allen,  Courteney Cox,  Chevy Chase,  Kat...  [United States]
# 8806  [Vicky Kaushal,  Sarah-Jane Dias,  Raaghav Cha...          [India]
#
#      date_added  release_year rating  \
# 0    2021-09-25          2020  PG-13
# 1    2021-09-24          2021  TV-MA
# 2    2021-09-24          2021  TV-MA
# 3    2021-09-24          2021  TV-MA
# 4    2021-09-24          2021  TV-MA
# ...         ...           ...    ...
# 8802 2019-11-20          2007      R
# 8803 2019-07-01          2018  TV-Y7
# 8804 2019-11-01          2009      R
# 8805 2020-01-11          2006     PG
# 8806 2019-03-02          2015  TV-14
#
#                                               listed_in  \
# 0                                       [Documentaries]
# 1     [International TV Shows,  TV Dramas,  TV Myste...
# 2     [Crime TV Shows,  International TV Shows,  TV ...
# 3                             [Docuseries,  Reality TV]
# 4     [International TV Shows,  Romantic TV Shows,  ...
# ...                                                 ...
# 8802                 [Cult Movies,  Dramas,  Thrillers]
# 8803         [Kids' TV,  Korean TV Shows,  TV Comedies]
# 8804                         [Comedies,  Horror Movies]
# 8805              [Children & Family Movies,  Comedies]
# 8806  [Dramas,  International Movies,  Music & Music...
#
#                                             description  minutes  seasons
# 0     As her father nears the end of his life, filmm...       90       -1
# 1     After crossing paths at a party, a Cape Town t...       -1        2
# 2     To protect his family from a powerful drug lor...       -1        1
# 3     Feuds, flirtations and toilet talk go down amo...       -1        1
# 4     In a city of coaching centers known to train I...       -1        2
# ...                                                 ...      ...      ...
# 8802  A political cartoonist, a crime reporter and a...      158       -1
# 8803  While living alone in a spooky town, a young g...       -1        2
# 8804  Looking to survive in a world taken over by zo...       88       -1
# 8805  Dragged from civilian life, a former superhero...       88       -1
# 8806  A scrappy but poor boy worms his way into a ty...      111       -1
#
# [8807 rows x 13 columns]

# %%
df['release_year']=df['release_year'].apply(lambda x: int(x))

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          Unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          Unknown
# 4         s5  TV Show           Kota Factory          Unknown
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb          Unknown
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast          country  \
# 0                                             [Unknown]  [United States]
# 1     [Ama Qamata,  Khosi Ngema,  Gail Mabalane,  Th...   [South Africa]
# 2     [Sami Bouajila,  Tracy Gotoas,  Samuel Jouy,  ...        [Unknown]
# 3                                             [Unknown]        [Unknown]
# 4     [Mayur More,  Jitendra Kumar,  Ranjan Raj,  Al...          [India]
# ...                                                 ...              ...
# 8802  [Mark Ruffalo,  Jake Gyllenhaal,  Robert Downe...  [United States]
# 8803                                          [Unknown]        [Unknown]
# 8804  [Jesse Eisenberg,  Woody Harrelson,  Emma Ston...  [United States]
# 8805  [Tim Allen,  Courteney Cox,  Chevy Chase,  Kat...  [United States]
# 8806  [Vicky Kaushal,  Sarah-Jane Dias,  Raaghav Cha...          [India]
#
#      date_added  release_year rating  \
# 0    2021-09-25          2020  PG-13
# 1    2021-09-24          2021  TV-MA
# 2    2021-09-24          2021  TV-MA
# 3    2021-09-24          2021  TV-MA
# 4    2021-09-24          2021  TV-MA
# ...         ...           ...    ...
# 8802 2019-11-20          2007      R
# 8803 2019-07-01          2018  TV-Y7
# 8804 2019-11-01          2009      R
# 8805 2020-01-11          2006     PG
# 8806 2019-03-02          2015  TV-14
#
#                                               listed_in  \
# 0                                       [Documentaries]
# 1     [International TV Shows,  TV Dramas,  TV Myste...
# 2     [Crime TV Shows,  International TV Shows,  TV ...
# 3                             [Docuseries,  Reality TV]
# 4     [International TV Shows,  Romantic TV Shows,  ...
# ...                                                 ...
# 8802                 [Cult Movies,  Dramas,  Thrillers]
# 8803         [Kids' TV,  Korean TV Shows,  TV Comedies]
# 8804                         [Comedies,  Horror Movies]
# 8805              [Children & Family Movies,  Comedies]
# 8806  [Dramas,  International Movies,  Music & Music...
#
#                                             description  minutes  seasons
# 0     As her father nears the end of his life, filmm...       90       -1
# 1     After crossing paths at a party, a Cape Town t...       -1        2
# 2     To protect his family from a powerful drug lor...       -1        1
# 3     Feuds, flirtations and toilet talk go down amo...       -1        1
# 4     In a city of coaching centers known to train I...       -1        2
# ...                                                 ...      ...      ...
# 8802  A political cartoonist, a crime reporter and a...      158       -1
# 8803  While living alone in a spooky town, a young g...       -1        2
# 8804  Looking to survive in a world taken over by zo...       88       -1
# 8805  Dragged from civilian life, a former superhero...       88       -1
# 8806  A scrappy but poor boy worms his way into a ty...      111       -1
#
# [8807 rows x 13 columns]

# %%
df.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added      datetime64[ns]
# release_year             int64
# rating                  object
# listed_in               object
# description             object
# minutes                  int64
# seasons                  int64
# dtype: object

# %% [markdown]
# <h1 style="color:#39FF14;font-size:40px;"> Lastly remove trailing and leading whitespaces from string columns</h1>

# %%
def rem_ws(x):
    return x.strip()

# %%
df['title']=df['title'].apply(rem_ws)
df['description']=df['description'].apply(rem_ws)

# %% [markdown]
# <h1 style="color:#39FF14;font-size:40px;"> Final Result:-</h1>

# %%
df.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added      datetime64[ns]
# release_year             int64
# rating                  object
# listed_in               object
# description             object
# minutes                  int64
# seasons                  int64
# dtype: object

# %%
df.describe().T
# Out:
#                count                           mean                  min  \
# date_added      8807  2019-05-17 12:13:09.735437568  2008-01-01 00:00:00
# release_year  8807.0                    2014.180198               1925.0
# minutes       8807.0                      68.982627                 -1.0
# seasons       8807.0                      -0.159192                 -1.0
#
#                               25%                  50%                  75%  \
# date_added    2018-04-06 00:00:00  2019-07-04 00:00:00  2020-08-18 00:00:00
# release_year               2013.0               2017.0               2019.0
# minutes                      -1.0                 88.0                106.0
# seasons                      -1.0                 -1.0                  1.0
#
#                               max        std
# date_added    2021-09-25 00:00:00        NaN
# release_year               2021.0   8.819312
# minutes                     312.0  51.944202
# seasons                      17.0   1.542229

# %%
df.isna().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# listed_in       0
# description     0
# minutes         0
# seasons         0
# dtype: int64

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water          Unknown
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans          Unknown
# 4      s5  TV Show           Kota Factory          Unknown
#
#                                                 cast          country  \
# 0                                          [Unknown]  [United States]
# 1  [Ama Qamata,  Khosi Ngema,  Gail Mabalane,  Th...   [South Africa]
# 2  [Sami Bouajila,  Tracy Gotoas,  Samuel Jouy,  ...        [Unknown]
# 3                                          [Unknown]        [Unknown]
# 4  [Mayur More,  Jitendra Kumar,  Ranjan Raj,  Al...          [India]
#
#   date_added  release_year rating  \
# 0 2021-09-25          2020  PG-13
# 1 2021-09-24          2021  TV-MA
# 2 2021-09-24          2021  TV-MA
# 3 2021-09-24          2021  TV-MA
# 4 2021-09-24          2021  TV-MA
#
#                                            listed_in  \
# 0                                    [Documentaries]
# 1  [International TV Shows,  TV Dramas,  TV Myste...
# 2  [Crime TV Shows,  International TV Shows,  TV ...
# 3                          [Docuseries,  Reality TV]
# 4  [International TV Shows,  Romantic TV Shows,  ...
#
#                                          description  minutes  seasons
# 0  As her father nears the end of his life, filmm...       90       -1
# 1  After crossing paths at a party, a Cape Town t...       -1        2
# 2  To protect his family from a powerful drug lor...       -1        1
# 3  Feuds, flirtations and toilet talk go down amo...       -1        1
# 4  In a city of coaching centers known to train I...       -1        2

# %%
df.to_csv('final_result.csv',index=False)
